# %% [markdown]
# #Test math markdown
#
# This is an inline \\( \Gamma \\), and a larger inline \\( \big\|\big\| Ax - b \big\|\big\| \\) set
#
# \\( f(\beta)= -Y_t^T X_t \beta + \sum log( 1+{e}^{X_t\bullet\beta}) + \frac{1}{2}\delta^t S_t^{-1}\delta\\)
#
# \\(c = \\pm\\sqrt{a^2 + b^2} \\)
#
# \\(A{_i}{_j}=B{_i}{_j}\\)
#
# $$c = \\pm\\sqrt{a^2 + b^2}$$
#
# \\[A{_i}{_j}=B{_i}{_j}\\]
